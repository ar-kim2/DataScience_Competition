# %% [markdown]
# <font size=6><b> House Prices - Advanced Regression Techniques
# * ref: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/leaderboard

# %% [markdown]
# <pre>
# SalePrice - 부동산 판매 가격 (Target) the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# MSSubClass: 건물 클래스 The building class
# MSZoning: 구역분류 The general zoning classification
# LotFrontage: 인접 길과의 거리 Linear feet of street connected to property
# LotArea: 부지 크기 Lot size in square feet
# Street: 도로 접근 유형 Type of road access
# Alley: 골목 집입 방식 Type of alley access
#
# LotShape: 부지모양  General shape of property
# LandContour: 부지의 평탄한 정도 Flatness of the property
# Utilities: 사용가능한 서비스 Type of utilities available
# LotConfig: 대지 구성 Lot configuration
# LandSlope: 부지의 기울기 Slope of property
# Neighborhood: Ames 시 경계 내의 물리적 위치 Physical locations within Ames city limits
# Condition1: 간선도로 또는 철도와의 인접 Proximity to main road or railroad
# Condition2: 주요 도로 또는 철도와의 근접성 Proximity to main road or railroad (if a second is present)
#
# BldgType: 주거 타입 Type of dwelling
# HouseStyle: 주거 스타일 Style of dwelling
# OverallQual: 재료 및 마감 품질 Overall material and finish quality
# OverallCond: 상태등급 Overall condition rating
# YearBuilt: 건설날짜 Original construction date
# YearRemodAdd: 리모델링 날짜 Remodel date
#
# RoofStyle: 지붕의 종류 Type of roof
# RoofMatl: 지붕재 Roof material
# Exterior1st: 주택 외부 피복재   Exterior covering on house
# Exterior2nd: 주택 외부 피복재 (재료가 둘 이상인 경우) Exterior covering on house (if more than one material)
# MasVnrType: 석조 베니어(판) 유형 Masonry veneer type
# MasVnrArea: 벽돌 베니어 영역 Masonry veneer area in square feet
# ExterQual: 외장재 품질 Exterior material quality
# ExterCond: 외부 자재의 현재 상태 Present condition of the material on the exterior
# Foundation: 기반의 종류 Type of foundation
#
# BsmtQual: 지하실의 높이 Height of the basement
# BsmtCond: 지하실의 일반적인 상태 General condition of the basement
# BsmtExposure: 지하실 벽 Walkout or garden level basement walls
# BsmtFinType1: 지하 마감면의 품질 Quality of basement finished area
# BsmtFinSF1: 마감 평방 피트 Type 1 finished square feet
# BsmtFinType2: 두번째 완성된 영역의 품질 (있는 경우) Quality of second finished area (if present)
# BsmtFinSF2: 마감 평방 피트 Type 2 finished square feet
# BsmtUnfSF: 지하 공간의 미완성 평방 피트 Unfinished square feet of basement area
# TotalBsmtSF: 지하 면적의 총 평방 피트 Total square feet of basement area
#
# Heating: 난방종류 Type of heating
# HeatingQC: 난방 품질 및 상태 Heating quality and condition
# CentralAir: 중앙 에어컨 Central air conditioning
# Electrical: 전기시스템 Electrical system
#
# 1stFlrSF: 1층 평간 피트 First Floor square feet
# 2ndFlrSF: 2층 평방 피트 Second floor square feet
# LowQualFinSF: 저품질 마감  평방 피트 (모든 층) Low quality finished square feet (all floors)
# GrLivArea: 지상 거실 면적 평방피트 Above grade (ground) living area square feet
#
# BsmtFullBath: 지하 Full 욕실, Basement full bathrooms
# BsmtHalfBath: 지하 Half 욕실 Basement half bathrooms
# FullBath: 지상층 Full 욕실 Full bathrooms above grade
# HalfBath: 지상층 Half 욕실 Half baths above grade
#
# Bedroom: 침실 수 Number of bedrooms above basement level
# Kitchen: 주방 수 Number of kitchens
# KitchenQual: 주방 품질 Kitchen quality
# TotRmsAbvGrd: 총 객실 수 (욕실 제외) Total rooms above grade (does not include bathrooms)
#
# Functional: 홈기능 등급 Home functionality rating
# Fireplaces: 벽난로 수 Number of fireplaces
# FireplaceQu: 벽난로 품질 Fireplace quality
#
# GarageType: 차고 위치 Garage location
# GarageYrBlt: 차고가 건설된 연도 Year garage was built
# GarageFinish: 차고 내부 마감 Interior finish of the garage
# GarageCars: 차고의 크기 (차량 수용력 기준) Size of garage in car capacity
# GarageArea: 차고의 크기 (평방 피트 단위) Size of garage in square feet
# GarageQual: 차고 품질 Garage quality
# GarageCond: 차고 상태 Garage condition
#
# PavedDrive: 포장된 집입로 Paved driveway
# WoodDeckSF: 목재 데크 면적(제곱피트) Wood deck area in square feet
# OpenPorchSF: 연린 베란다 영역 Open porch area in square feet
# EnclosedPorch: 닫힌 현관 면적 Enclosed porch area in square feet
# 3SsnPorch: season Proch 영역 (Porch: 건물의 입구에 지붕을 갖추어 차를 대도록 한 곳) Three season porch area in square feet
# ScreenPorch: 유리 porch 영역 Screen porch area in square feet
#
# PoolArea: 수영장 면적 Pool area in square feet
# PoolQC: 수영장 품질 Pool quality
# Fence: 울타리 품질 Fence quality
# MiscFeature: 기타 기능 Miscellaneous feature not covered in other categories
# MiscVal: 기타 기능의 $Value  $Value of miscellaneous feature
#
# MoSold: 판매 월 Month Sold
# YrSold: 판매 연도Year Sold
# SaleType: 판매 유형 Type of sale
# SaleCondition: 판매 조건 Condition of sale

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

sns.set() 
#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'  # 한글 처리
plt.rcParams['axes.unicode_minus'] = False  # -, $ 등등에 표현 특수기호로 버리지 말고 다 써줘라.

# %%
import pandas_profiling

# %% [markdown]
# # Data load

# %%
train = pd.read_csv('./datasets/train.csv')
test = pd.read_csv('./datasets/test.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Drop ID

# %%
train = train.drop('Id', axis=1)
test = test.drop('Id', axis=1)

# %% [markdown]
# ## 날짜 관련
# * 'YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold' (5개)
# * 'GarageYrBlt', YearBuilt' : High Correlation, 보통 건물을 지을 때, 주차장을 함께 짖는다.
# * 'GarageYrBlt' : 결측 81개, 차고가 없는 경우에 해당.
#     * [방법1] 'YearBuilt'로 결측처리
#     * [방법2] 'YearBuilt'와 다중공선 관계를 가지기 때문에 삭제해도 될듯
# * 'MoSold','YrSold' : OneHotEncoding 필요
# * 'YearBuilt', 'YearRemodAdd' : Target과 높은 선형 관계를 가짐. 주요 피쳐로 판단됨.
#     * Scaling만 해서 입력으로 넣어주면 될듯
# * Remodeling 여부, 파생피쳐 생성

# %%
col_list = ['YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold', 'SalePrice']

df = train[col_list]
# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report1_날짜관련.html')

# %% [markdown]
# ### 결측 확인

# %%
# train data 결측확인
col_list = ['YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold']
train[col_list].isna().sum()
# Out:
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt     81
# MoSold           0
# YrSold           0
# dtype: int64

# %%
# test data 결측확인
test[col_list].isna().sum()
# Out:
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt     78
# MoSold           0
# YrSold           0
# dtype: int64

# %%
# GarageYrBlt 결측, GarageType이 None인 경우에 해당.
# 즉 Garage가 없는 경우, None임.
print(train['GarageYrBlt'].isna().sum())
print(train['GarageType'].isna().sum())
print(train[(train['GarageYrBlt'].isna())&(train['GarageType'].isna())].shape)
# Out:
# 81
# 81
# (81, 80)

# %%
# Test data 확인
print(test['GarageYrBlt'].isna().sum())
print(test['GarageType'].isna().sum())
print(test[(train['GarageYrBlt'].isna())&(test['GarageType'].isna())].shape)
test[(test['GarageYrBlt'].isna())&(test['GarageType'].notna())][['GarageYrBlt','GarageType']]
# Out:
# 78
# 76
# (5, 79)
#       GarageYrBlt GarageType
# 666           NaN     Detchd
# 1116          NaN     Detchd

# %%
garageNa_idx = train[train['GarageYrBlt'].isna()].index.values
train.loc[garageNa_idx, 'GarageYrBlt'] = train.loc[garageNa_idx, 'YearBuilt']

garageNa_idx = test[test['GarageYrBlt'].isna()].index.values
test.loc[garageNa_idx, 'GarageYrBlt'] = test.loc[garageNa_idx, 'YearBuilt']

train['GarageYrBlt'].isna().sum(), test['GarageYrBlt'].isna().sum()
# Out:
# (0, 0)

# %% [markdown]
# ### Objective 확인

# %%
# object type columns
train[col_list].select_dtypes('object').columns
# Out:
# Index([], dtype='object')

# %%
train[col_list].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   YearBuilt     1460 non-null   int64
#  1   YearRemodAdd  1460 non-null   int64
#  2   GarageYrBlt   1460 non-null   float64
#  3   MoSold        1460 non-null   int64
#  4   YrSold        1460 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 57.2 KB

# %% [markdown]
# ### Onehot Encoding
# * 'MoSold','YrSold'

# %%
col_list = ['YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold', 'SalePrice']
df = train[col_list]
df = pd.get_dummies(df, columns=['MoSold','YrSold'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   YearBuilt     1460 non-null   int64
#  1   YearRemodAdd  1460 non-null   int64
#  2   GarageYrBlt   1460 non-null   float64
#  3   SalePrice     1460 non-null   int64
#  4   MoSold_1      1460 non-null   uint8
#  5   MoSold_2      1460 non-null   uint8
#  6   MoSold_3      1460 non-null   uint8
#  7   MoSold_4      1460 non-null   uint8
#  8   MoSold_5      1460 non-null   uint8
#  9   MoSold_6      1460 non-null   uint8
#  10  MoSold_7      1460 non-null   uint8
#  11  MoSold_8      1460 non-null   uint8
#  12  MoSold_9      1460 non-null   uint8
#  13  MoSold_10     1460 non-null   uint8
#  14  MoSold_11     1460 non-null   uint8
#  15  MoSold_12     1460 non-null   uint8
#  16  YrSold_2006   1460 non-null   uint8
#  17  YrSold_2007   1460 non-null   uint8
# ...

# %% [markdown]
# ### 상관계수 확인

# %%
plt.figure(figsize=(15,  15))
sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
col_list = ['YearBuilt','YearRemodAdd','GarageYrBlt','SalePrice']
df = train[col_list]

fig, axes = plt.subplots(1, 3, figsize=(10, 3))

for i, col in enumerate(col_list):
    if i < 3:
        sns.scatterplot(df, x=col, y='SalePrice', ax=axes[i])
    
plt.tight_layout()
plt.show()

# %%
col_list = ['MoSold','YrSold','SalePrice']
df = train[col_list]

fig, axes = plt.subplots(1, 2, figsize=(10, 3))

for i, col in enumerate(col_list):
    if i < 2:
        sns.barplot(df, x=col, y='SalePrice', ax=axes[i])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 집 총평
# * 12 개
# *  'OverallQual','OverallCond','KitchenQual','HeatingQC','FireplaceQu','ExterQual','ExterCond','BsmtQual','BsmtCond','GarageQual','GarageCond','PoolQC'
#     * OverallQual: Target값과 높은 상관관계, 중요 Feature **
#     * PoolQC : Target 값과 상관관계가 있음.
#         * 결측치가 1400여건, 대부분 수영장이 없는 경우임.
#         * 수영장이 있는 데이터가 train이 7건, test가 3건
#         * BsmtQual과 높은 상관관계, 수영장을 지으려면 지하실 재료부터 고급으로 써야함.
#     * OverallCond: 5일 때가 가장 높고, 그 이상과 이하 구간으로 유사패턴을 보임.
#         * OverallCond, OverallQual와 약한 음의 상관관계를 보임.
#         * Target과도 약한 음의 상관관계를 보임.
#         * <b>추가</b> 확인 필요
#     * KitchenQual, ExterQual, BsmtQual --> OverallQual와 다중공선
#         * OverallQual와 상대적으로 연관성이 적은 그외 Qual Feature -->  HeatingQC, FireplaceQu, GarageQual
#     * GarageQual 와 GarageCond이 높은 상관관계
#
#     * <b>TODO:</b> 그외 Feature들 Target 과 연관성 추가 분석해야함.

# %%
col_list = ['OverallQual','OverallCond','KitchenQual','HeatingQC','FireplaceQu',
            'ExterQual','ExterCond','BsmtQual','BsmtCond','GarageQual','GarageCond','PoolQC', 'SalePrice']
df = train[col_list]
# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report2_집총평.html')

# %% [markdown]
# ### 결측 처리

# %%
# train data 결측확인
col_list = ['OverallQual','OverallCond','KitchenQual','HeatingQC','FireplaceQu',
            'ExterQual','ExterCond','BsmtQual','BsmtCond','GarageQual','GarageCond','PoolQC', 'SalePrice']
train[col_list].isna().sum()
# Out:
# OverallQual       0
# OverallCond       0
# KitchenQual       0
# HeatingQC         0
# FireplaceQu     690
# ExterQual         0
# ExterCond         0
# BsmtQual         37
# BsmtCond         37
# GarageQual       81
# GarageCond       81
# PoolQC         1453
# SalePrice         0
# dtype: int64

# %%
# test data 결측확인
col_list = ['OverallQual','OverallCond','KitchenQual','HeatingQC','FireplaceQu',
            'ExterQual','ExterCond','BsmtQual','BsmtCond','GarageQual','GarageCond','PoolQC']
test[col_list].isna().sum()
# Out:
# OverallQual       0
# OverallCond       0
# KitchenQual       1
# HeatingQC         0
# FireplaceQu     730
# ExterQual         0
# ExterCond         0
# BsmtQual         44
# BsmtCond         45
# GarageQual       78
# GarageCond       78
# PoolQC         1456
# dtype: int64

# %%
# 차고나, 난로, 지하실 등이 없어서 Nan인 경우가 있음.
# object type은 No로, 수치형은 0d으로 채움.

# Test data의 일부 columns에 차고나, 난로, 지하실등이 존재하는데 관련 Feature가 null인 경우가 있음.
# model학습시, 고려하여 처리해주어야함

obcol_list = train[col_list].select_dtypes('object').columns
train[obcol_list].fillna('No')
test[obcol_list].fillna('No')

numcol_list = train[col_list].select_dtypes(exclude='object').columns
train[obcol_list].fillna(0)
test[obcol_list].fillna(0)
# Out:
#      KitchenQual HeatingQC FireplaceQu ExterQual ExterCond BsmtQual BsmtCond  \
# 0             TA        TA           0        TA        TA       TA       TA
# 1             Gd        TA           0        TA        TA       TA       TA
# 2             TA        Gd          TA        TA        TA       Gd       TA
# 3             Gd        Ex          Gd        TA        TA       TA       TA
# 4             Gd        Ex           0        Gd        TA       Gd       TA
# ...          ...       ...         ...       ...       ...      ...      ...
# 1454          TA        Gd           0        TA        TA       TA       TA
# 1455          TA        TA           0        TA        TA       TA       TA
# 1456          TA        Ex          TA        TA        TA       TA       TA
# 1457          TA        TA           0        TA        TA       Gd       TA
# 1458          TA        Ex          TA        TA        TA       Gd       TA
#
#      GarageQual GarageCond PoolQC
# ...

# %% [markdown]
# ### 상관계수 확인
# * 해당 컬럼들은 object type의 숫자가 가치를 나타내는 정도이기 때문에
# OnehotEncoding하지 않고, replace하여 상관계수 확인함.

# %%
col_list = ['OverallQual','OverallCond','KitchenQual','HeatingQC','FireplaceQu',
            'ExterQual','ExterCond','BsmtQual','BsmtCond','GarageQual','GarageCond','PoolQC', 'SalePrice']
df = train[col_list]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1460 non-null   int64
#  1   OverallCond  1460 non-null   int64
#  2   KitchenQual  1460 non-null   object
#  3   HeatingQC    1460 non-null   object
#  4   FireplaceQu  770 non-null    object
#  5   ExterQual    1460 non-null   object
#  6   ExterCond    1460 non-null   object
#  7   BsmtQual     1423 non-null   object
#  8   BsmtCond     1423 non-null   object
#  9   GarageQual   1379 non-null   object
#  10  GarageCond   1379 non-null   object
#  11  PoolQC       7 non-null      object
#  12  SalePrice    1460 non-null   int64
# dtypes: int64(3), object(10)
# memory usage: 148.4+ KB

# %%
obcol_list = df.select_dtypes('object').columns

for col in obcol_list:
    df[col] = df[col].replace(['Ex','Gd','TA','Fa','Po','No'], [5, 4, 3, 2, 1, 0])

plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
# 대부분 Qual, Con관련 Feature들은 SalePrice와 양의 상관관계
# OverallCond (2, 5), Outlier 확인
# ExterCond 3, GarageCond 3,4 확인 필요
# PoolQC는 연관성은 있으나, 수영장이 있는 데이터가 너무 적음. 해당부분 처리 필요

col_list = df.columns

fig, axes = plt.subplots(5, 3, figsize=(10, 15))

for i, col in enumerate(col_list):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### OverallCond, ExterCond, GarageCond
# * 다른 패턴을 보이는 Feature

# %%
# OverallCond (2, 5), Outlier 확인
# ExterCond 3, GarageCond 3,4 확인 필요
# 대부분의 데이터가 ExterCond, GarageCond은 3,4로 추정되고
# 이 Feature로 인한 가격의 영향은 크지 않아 보임.

fig, axes = plt.subplots(1, 3, figsize=(10, 3))
sns.scatterplot(df, x='OverallCond', y = 'SalePrice', ax=axes[0])
sns.scatterplot(df, x='ExterCond', y = 'SalePrice', ax=axes[1])
sns.scatterplot(df, x='GarageCond', y = 'SalePrice', ax=axes[2])
plt.show()

# %% [markdown]
# ## 판매 관련
# * 7 개
# * 'SaleType','SaleCondition','MSSubClass','MSZoning','BldgType','HouseStyle','Functional'
#
# * <b> MSSubClass: float type이지만 15개의 Class임. 이를 구분해야함. (다시 Grouping) </b>
#     * HouseStyle :  MSSubClass와 연결가능할 듯
#     * MSSubClass, HouseStyle, BldgType으로 재 Grouping해야함.
#     * BldgType : MSSubClass와 High Correlation
# * <b>MSZoning: RP에서 공원 분리해야할 듯. </b>
#     * RL :Residential Low Density  (주거, 저밀도)
#     * RP :Residential Low Density Park (주거, 저밀도 with 공원)
# * Functional: 집의 하자 유무
#     * Min1이 가장 하자가 없다를 의미.
#     * <b>숫자로 라벨링해야함.</b>

# %%
col_list = ['SaleType','SaleCondition','MSSubClass','MSZoning','BldgType','HouseStyle','Functional', 'SalePrice']
df = train[col_list]
df.shape

# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report3_판매관련.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
col_list = ['SaleType','SaleCondition','MSSubClass','MSZoning','BldgType','HouseStyle','Functional']
test[col_list].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SaleType       1458 non-null   object
#  1   SaleCondition  1459 non-null   object
#  2   MSSubClass     1459 non-null   int64
#  3   MSZoning       1455 non-null   object
#  4   BldgType       1459 non-null   object
#  5   HouseStyle     1459 non-null   object
#  6   Functional     1457 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 79.9+ KB

# %% [markdown]
# ### 결측처리

# %%
# train data 결측확인
col_list = ['SaleType','SaleCondition','MSSubClass','MSZoning','BldgType','HouseStyle','Functional']
train[col_list].isna().sum()
# Out:
# SaleType         0
# SaleCondition    0
# MSSubClass       0
# MSZoning         0
# BldgType         0
# HouseStyle       0
# Functional       0
# dtype: int64

# %%
test[col_list].isna().sum()
# Out:
# SaleType         1
# SaleCondition    0
# MSSubClass       0
# MSZoning         4
# BldgType         0
# HouseStyle       0
# Functional       2
# dtype: int64

# %%
test['SaleType'].fillna(test['SaleType'].mode().values[0])
test['MSZoning'].fillna(test['MSZoning'].mode().values[0])
test['Functional'].fillna(test['Functional'].mode().values[0])
# Out:
# array(['WD'], dtype=object)

# %% [markdown]
# ### Functional

# %%
train['Functional'] = train['Functional'].replace(['Typ', 'Min1','Min2','Mod','Maj1', 'Maj2', 'Sev','Sal'], 
                                                [8, 7, 6, 5, 4, 3, 2, 1])
test['Functional'] = test['Functional'].replace(['Typ','Min1','Min2','Mod','Maj1', 'Maj2', 'Sev','Sal'], 
                                                [8, 7, 6, 5, 4, 3, 2, 1])

# %% [markdown]
# ### Target과의 연관성확인

# %%
col_list = ['SaleType','SaleCondition','MSSubClass','MSZoning','BldgType','HouseStyle','Functional','SalePrice']
df= train[col_list]

sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
col_list = ['SaleType','SaleCondition','MSSubClass','MSZoning','BldgType','HouseStyle','Functional','SalePrice']
df= train[col_list]

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, col in enumerate(col_list):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 전용면적
# * 7 개
# * 'GrLivArea','1stFlrSF','2ndFlrSF','LotArea','LandSlope','LandContour', 'LotShape', 'LotConfig'
# * 1stFlrSF,  'GrLivArea'**, 'LotArea' : Target과 높은 연관성, 주요 Feature **
# * '2ndFlrSF'는 'GrLivArea'와 높은 상관관계를 갖는데, Target과는 연관성이 높지 않음.
#     * 필요에 따라 삭제고려
# * LandSlope: 라벨링 해야함.
#     * Sev: 0, Mod : 1, Gtl : 2
# * LotShape: 라벨링 필요
#     * Reg:0, IR1: 1, IR2: 2,IR3: 3
# * LandContour: 카테고리성으로 판단됨.
# * LotConfig: 카테고리성

# %%
col_list = ['GrLivArea','1stFlrSF','2ndFlrSF','LotArea','LandSlope','LandContour', 'LotShape', 'LotConfig', 'SalePrice']
df = train[col_list]

# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report4_전용면적.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 결측확인
# * 결측 없음.

# %%
# train data 결측확인
col_list = ['GrLivArea','1stFlrSF','2ndFlrSF','LotArea','LandSlope','LandContour', 'LotShape', 'LotConfig']
train[col_list].isna().sum()
# Out:
# GrLivArea      0
# 1stFlrSF       0
# 2ndFlrSF       0
# LotArea        0
# LandSlope      0
# LandContour    0
# LotShape       0
# LotConfig      0
# dtype: int64

# %%
test[col_list].isna().sum()
# Out:
# GrLivArea      0
# 1stFlrSF       0
# 2ndFlrSF       0
# LotArea        0
# LandSlope      0
# LandContour    0
# LotShape       0
# LotConfig      0
# dtype: int64

# %%
train[col_list].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GrLivArea    1460 non-null   int64
#  1   1stFlrSF     1460 non-null   int64
#  2   2ndFlrSF     1460 non-null   int64
#  3   LotArea      1460 non-null   int64
#  4   LandSlope    1460 non-null   object
#  5   LandContour  1460 non-null   object
#  6   LotShape     1460 non-null   object
#  7   LotConfig    1460 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 91.4+ KB

# %%
col_list = ['YearBuilt','YearRemodAdd','GarageYrBlt','SalePrice']
df = train[col_list]

fig, axes = plt.subplots(1, 3, figsize=(10, 3))

for i, col in enumerate(col_list):
    if i < 3:
        sns.scatterplot(df, x=col, y='SalePrice', ax=axes[i])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### LandSlope, LotShape
# * 등급을 나타내는 object type, 라벨링해줌.

# %%
train['LandSlope'] = train['LandSlope'].replace(['Gtl','Mod','Sev'],[1, 2, 3])
test['LandSlope'] = test['LandSlope'].replace(['Gtl','Mod','Sev'],[1, 2, 3])

# %%
train['LotShape'] = train['LotShape'].replace(['Reg','IR1','IR2','IR3'], [0, 1, 2, 3])
test['LotShape'] = test['LotShape'].replace(['Reg','IR1','IR2','IR3'], [0, 1, 2, 3])

# %% [markdown]
# ### Target과의 연관성 확인

# %%
col_list = ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'LotArea', 'SalePrice']
df = train[col_list]

sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
col_list = ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'LotArea', 'SalePrice']
df = train[col_list]

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, col in enumerate(col_list):
    i1 = i//3
    i2 = i%3
        
    sns.scatterplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %%
col_list = ['LandSlope','LandContour', 'LotShape', 'LotConfig', 'SalePrice']
df = train[col_list]

fig, axes = plt.subplots(2, 3, figsize=(10, 8))

for i, col in enumerate(col_list):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 내부시설(구조물갯수,난방)
# * 11개
# * 'TotRmsAbvGrd','BedroomAbvGr','FullBath','HalfBath','KitchenAbvGr','Utilities','Heating','HeatingQC','Fireplaces','CentralAir','Electrical'
# * 'TotRmsAbvGrd' : Target 과 높은 상관관계, 주요 Feature **
#     * BedroomAbvGr과 연관성이 높음, But BedroomAbvGr과 Target과는 연관성이 높지 않기 때문에,
#         * BedroomAbvGr를 지우고, 지우지 않고 확인 필요
# * FullBath, HalfBath, KitchenAbvGr, Fireplaces
#     : 수치형으로 변경해야함.
# * Utilities
#     * Descriptpion에는 4개인데, 2개 밖에 없음.
# * Heating, Electrical
#     : 카테고리성, OnehotEncoding
# * HeatingQC
#     * Labeling 해야함.
# * CentralAir : 0/1로 구분

# %%
col_list = ['TotRmsAbvGrd','BedroomAbvGr','FullBath','HalfBath','KitchenAbvGr','Utilities','Heating','HeatingQC','Fireplaces','CentralAir','Electrical', 'SalePrice']
df = train[col_list]

# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report5_내부시설.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 결측처리

# %%
# train data 결측확인
col_list = ['TotRmsAbvGrd','BedroomAbvGr','FullBath','HalfBath','KitchenAbvGr','Utilities','Heating','HeatingQC','Fireplaces','CentralAir','Electrical']
train[col_list].isna().sum()
# Out:
# TotRmsAbvGrd    0
# BedroomAbvGr    0
# FullBath        0
# HalfBath        0
# KitchenAbvGr    0
# Utilities       0
# Heating         0
# HeatingQC       0
# Fireplaces      0
# CentralAir      0
# Electrical      1
# dtype: int64

# %%
test[col_list].isna().sum()
# Out:
# TotRmsAbvGrd    0
# BedroomAbvGr    0
# FullBath        0
# HalfBath        0
# KitchenAbvGr    0
# Utilities       2
# Heating         0
# HeatingQC       0
# Fireplaces      0
# CentralAir      0
# Electrical      0
# dtype: int64

# %%
train['Electrical'] = train['Electrical'].fillna(0)
test['Utilities'] = test['Utilities'].fillna(test['Utilities'].mode()[0])

# %% [markdown]
# ### Target과의 연관성 확인

# %%
col_list = ['TotRmsAbvGrd','BedroomAbvGr','FullBath','HalfBath','KitchenAbvGr','Utilities','Heating','HeatingQC','Fireplaces','CentralAir','Electrical', 'SalePrice']
df = train[col_list]

sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
col_list = ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'LotArea', 'SalePrice']
df = train[col_list]

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, col in enumerate(col_list):
    i1 = i//3
    i2 = i%3
        
    sns.scatterplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %%
col_list = ['LandSlope','LandContour', 'LotShape', 'LotConfig', 'SalePrice']
df = train[col_list]

fig, axes = plt.subplots(2, 3, figsize=(10, 8))

for i, col in enumerate(col_list):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 외부시설
# * 21 개
# - porch*, WoodDeckSF  ['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#    'ScreenPorch', ]
# - 지하실 : Bsmt*  ['BsmtExposure', 'BsmtFinType1',  'BsmtFinType2','TotalBsmtSF',]
# - 차고지: Garage*  ['GarageType','GarageFinish', 'GarageCars', 'GarageArea']
# - 공사진행여부 ['LowQualFinSF','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF']
# - 기타자산 Pool, Mise ['PoolArea','PoolQC','MiscVal','MiscFeature']

# %%
col_list = ['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch','BsmtExposure', 'BsmtFinType1',  'BsmtFinType2','TotalBsmtSF','GarageType','GarageFinish', 'GarageCars', 
            'GarageArea', 'LowQualFinSF','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF', 'PoolArea','PoolQC','MiscVal','MiscFeature', 'SalePrice']
df = train[col_list]

# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report6_외부시설.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 결측확인
# * 결측 없음.

# %%
# train data 결측확인
col_list = ['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch','BsmtExposure', 'BsmtFinType1',  'BsmtFinType2','TotalBsmtSF','GarageType','GarageFinish', 'GarageCars', 
            'GarageArea', 'LowQualFinSF','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF', 'PoolArea','PoolQC','MiscVal','MiscFeature']
train[col_list].isna().sum()
# Out:
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# TotalBsmtSF         0
# GarageType         81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# LowQualFinSF        0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtUnfSF           0
# PoolArea            0
# PoolQC           1453
# MiscVal             0
# MiscFeature      1406
# dtype: int64

# %%
test[col_list].isna().sum()
# Out:
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinType2       42
# TotalBsmtSF         1
# GarageType         76
# GarageFinish       78
# GarageCars          1
# GarageArea          1
# LowQualFinSF        0
# BsmtFinSF1          1
# BsmtFinSF2          1
# BsmtUnfSF           1
# PoolArea            0
# PoolQC           1456
# MiscVal             0
# MiscFeature      1408
# dtype: int64

# %%
objcol = train[col_list].select_dtypes('object').columns
for col in objcol:
    train[col] = train[col].fillna(train[col].mode()[0])
    test[col] = test[col].fillna(test[col].mode()[0])
    
numcol = train[col_list].select_dtypes(exclude='object').columns
for col in numcol:
    train[col] = train[col].fillna(0)
    test[col] = test[col].fillna(0)

# %% [markdown]
# ### Target과의 연관성 확인

# %%
col_list =  ['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch','BsmtExposure', 'BsmtFinType1',  'BsmtFinType2','TotalBsmtSF','GarageType','GarageFinish', 'GarageCars', 
            'GarageArea', 'LowQualFinSF','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF', 'PoolArea','PoolQC','MiscVal','MiscFeature', 'SalePrice']
df = train[col_list]

sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
numcol = ['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'TotalBsmtSF', 'GarageCars', 'GarageArea',
       'LowQualFinSF', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'PoolArea',
       'MiscVal', 'SalePrice']
df = train[numcol]

fig, axes = plt.subplots(5, 3, figsize=(10, 18))

for i, col in enumerate(numcol):
    i1 = i//3
    i2 = i%3
        
    sns.scatterplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %%
numcol = ['BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'GarageType',
       'GarageFinish', 'PoolQC', 'MiscFeature', 'SalePrice']
df = train[numcol]

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, col in enumerate(numcol):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 외장재
# * 8개
# * Exter* , MasVnr*, FenseRoof
# * ['Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'MasVnrType', 'MasVnrArea', 'RoofStyle', 'RoofMatl', 'Fence']
# * Exterior1st, Exterior2nd: High Correlation
# * ExterQual : Target과 연관성이 있음.
#     * Labeling 해야함.
# * ExterCond
#     * Labeling 해야함.
# * MasVnrType, RoofStyle, RoofMatl
#     * 카테고리, Onehot Encoding 필요
#
# * Fence: 결측 처리 해야함.
#     * 연관성은 없다고 판단됨.

# %%
col_list = ['Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'MasVnrType', 'MasVnrArea', 'RoofStyle', 'RoofMatl', 'Fence', 'SalePrice']
df = train[col_list]

# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report7_외장재.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(15, 5))
sns.histplot(train, x= 'Exterior1st')
plt.show()

# %% [markdown]
# ### 결측처리

# %%
train['Fence'] = train['Fence'].fillna('No')
test['Fence'] = test['Fence'].fillna('No')

# %%
train['MasVnrType'] = train['MasVnrType'].fillna(train['MasVnrType'].mode().values[0])
test['MasVnrType'] = test['MasVnrType'].fillna(test['MasVnrType'].mode().values[0])

# %%
train['MasVnrArea'] = train['MasVnrArea'].fillna(0)
test['MasVnrArea'] = test['MasVnrArea'].fillna(0)

# %% [markdown]
# ### Target과의 연관성 확인

# %%
col_list =  ['Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'MasVnrType', 'MasVnrArea', 'RoofStyle', 'RoofMatl', 'Fence', 'SalePrice']
df = train[col_list]

sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
numcol = ['Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'MasVnrType', 'RoofStyle', 'RoofMatl', 'Fence', 'SalePrice']
df = train[numcol]

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, col in enumerate(numcol):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %%
sns.lmplot(train, x='MasVnrArea', y='SalePrice')
plt.show()

# %% [markdown]
# ## 도로
#   - 7개
#   - 포장 : Street, PavedDrive, Alley
#   - 접근성 : Condition1, Condition2, Neighborhood, LotFrontage
#
# * Alley: No 결측 처리해야함.
#     * Street, Condition2, Neighborhood 와 높은 상관관계
#     * Street와 다중공선이라서 삭제 필요.
# * PavedDrive: 포장된 차로
#     * Labeling 처리, Dirt/Gravel:0, Partial Pavement:1, Paved: 2
# * Street: 카테고리성
# * Condition1과 Condition2 함께 OnehotEncoding 해야함.
# * Neighborhood: 카테고리성은 맞는데, unique 25개 데이터임 --> OnehotEncoding 어떻게 할지 고려해보아야함.
# * LotFrontage
#     * 결측처리해야함.
#     * 0으로 처리

# %%
col_list = ['Street', 'PavedDrive', 'Alley', 'Condition1', 'Condition2', 'Neighborhood', 'LotFrontage', 'SalePrice' ]
df = train[col_list]

# report = pandas_profiling.ProfileReport(df)
# report.to_file('./eda_report8_도로.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 결측 처리

# %%
train[train['Alley'].isna()].shape
# Out:
# (1369, 80)

# %%
train['Alley'] = train['Alley'].fillna('No')
test['Alley'] = test['Alley'].fillna('No')

# %%
### LotFrontage 결측 처리
train['LotFrontage'] = train['LotFrontage'].fillna(0)
test['LotFrontage'] = test['LotFrontage'].fillna(0)

# %% [markdown]
# ### Target과의 연관성 확인

# %%
col_list =  ['Street', 'PavedDrive', 'Alley', 'Condition1', 'Condition2', 'Neighborhood', 'LotFrontage', 'SalePrice' ]
df = train[col_list]

sns.heatmap(df.corr(), fmt='.2f', annot=True)
plt.show()

# %%
numcol = ['Street', 'PavedDrive', 'Alley', 'Condition1', 'Condition2', 'Neighborhood', 'SalePrice' ]
df = train[numcol]

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, col in enumerate(numcol):
    i1 = i//3
    i2 = i%3
        
    sns.barplot(df, x=col, y='SalePrice', ax=axes[i1][i2])
    
plt.tight_layout()
plt.show()

# %%
sns.lmplot(train, x='LotFrontage', y='SalePrice')
plt.show()
